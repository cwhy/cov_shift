# %%
import toy_data.cov_shift as data_gen
import toy_data as td
import bokeh.io
import numpy as np
import bokeh.plotting as bp
import bokeh.charts as bc
import matplotlib.pyplot as plt
import tensorflow as tf
bokeh.io.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="77fe642b-4df6-494c-841b-c1f9598b07c5">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="77fe642b-4df6-494c-841b-c1f9598b07c5">Loading BokehJS ...</span>
#     </div>

# %%
# m_ = td.models.LinearBinary(2)
m_ = td.models.rotatedSine2D(phase=np.pi/2, frequency=1)
data = data_gen.Gaussian_Shift_2D_BinaryClassification(m_,
                                                       tst_X_mean_shift=(-3, -2.5),
                                                       noise_sd=0.4,
                                                       n_samples=400)
data_gen.visualize_2D_classification(data, classifyF=m_, fig_width=800)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="ce643022-8a8f-4b12-b6a9-13620177ebde"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("ce643022-8a8f-4b12-b6a9-13620177ebde");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("ce643022-8a8f-4b12-b6a9-13620177ebde");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'ce643022-8a8f-4b12-b6a9-13620177ebde' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"34628ee8-0fbe-4cb0-b190-88750b7bfd0b":{"roots":{"references":[{"attributes":{"data_source":{"id":"92ab0c01-1203-4ead-8bd1-b842985f7ffc","type":"ColumnDataSource"},"glyph":{"id":"d92165db-a41d-446a-8614-c4cad7dfed69","type":"Cross"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"0c2eb647-a992-4e3b-a57a-451ff9a70014","type":"Cross"},"selection_glyph":null},"id":"f4351815-f67a-422f-ab9a-7acf5acd3104","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"68dcafd3-f29e-4f6b-9e4f-5ce1c0248747","type":"ColumnDataSource"},"glyph":{"id":"7c2ce913-875e-4089-a0a4-d6004c81ef55","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"2cb42dfc-5014-4cb4-aa08-9a325d295067","type":"Circle"},"selection_glyph":null},"id":"d7dd1124-5e9f-4853-a6a0-c7800dfec447","type":"GlyphRenderer"},{"attributes":{},"id":"3a6ceb34-08c9-4c3c-a58e-ec13043ae600","type":"ToolEvents"},{"attributes":{},"id":"3241ad94-123f-4a67-a5a4-43513514c200","type":"BasicTickFormatter"},{"attributes":{"callback":null,"end":6.39240508199437,"start":-4.646821345749968},"id":"e11c0339-385e-4914-aeb1-a790ddf65d9a","type":"Range1d"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"56be4dbf-7524-422c-ab99-f90cb991e148","type":"PanTool"},{"id":"f8f84fa1-b3df-4492-acf4-afc6541a55da","type":"WheelZoomTool"},{"id":"608e6f17-240e-440d-a667-7a8c65137167","type":"BoxZoomTool"},{"id":"e401857a-33af-464c-9a47-cf6ff9c1d66d","type":"SaveTool"},{"id":"be9c1df9-6982-4923-9dc6-35eabe25d913","type":"ResetTool"},{"id":"c9a72aca-9610-4aeb-aa03-4527ef873b26","type":"HelpTool"}]},"id":"9ee94d56-0324-4425-95d6-b444e156f871","type":"Toolbar"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"IYlDzFoV/L9b7f3xKJQEwF90CCXoS/e/0paTjlJyB8DirJ7jxhAAwBgMzULa3A3AhkUq/9qUDsBO6TfjFcIAwFunPMhpOgDA4DcnPZ0M97+/fgHrojP3v5cdzwY9jfK/5QjP4F6W87/83963u7wOwJK/ZgrSruK/NnrJtK2q478=","dtype":"float64","shape":[16]},"y":{"__ndarray__":"LqCtAk7AC8Ap9HU8TkwIwHuGtH8JpQnAdo9zq6vCDcBwkou+SwANwFVMxKI6ugnAfOqKmoSFDcAARcW1lp0LwF7eLMayvQXANsWm5I1lEcCPwaghsSf6vxrY8CISMwTAyv93rTh+B8Bbgau+wwMFwLgL7yX2W+a/jjNPw2DMCMA=","dtype":"float64","shape":[16]}}},"id":"939ab658-ded2-493a-bf49-21f201976584","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.6},"fill_color":{"value":"#883829"},"line_alpha":{"value":0.6},"line_color":{"value":"#883829"},"line_width":{"value":1.5},"size":{"units":"screen","value":9},"x":{"field":"x"},"y":{"field":"y"}},"id":"7c2ce913-875e-4089-a0a4-d6004c81ef55","type":"Circle"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[147]},"y":{"__ndarray__":"...","dtype":"float64","shape":[147]}}},"id":"29bc3401-14d8-49fc-9728-e17218c99e50","type":"ColumnDataSource"},{"attributes":{"dh":{"field":"dh","units":"data"},"dw":{"field":"dw","units":"data"},"image":{"field":"image"},"x":{"field":"x"},"y":{"field":"y"}},"id":"e9c684c8-8be3-4be9-8a0e-c121a4944b10","type":"ImageRGBA"},{"attributes":{"plot":null,"text":""},"id":"b7d746fc-ee3c-4bd7-9d46-120d433db3f2","type":"Title"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":1.5},"size":{"units":"screen","value":9},"x":{"field":"x"},"y":{"field":"y"}},"id":"2cb42dfc-5014-4cb4-aa08-9a325d295067","type":"Circle"},{"attributes":{"dimension":1,"plot":{"id":"7b40001c-9253-4dd2-a062-dcc3107cc9e2","subtype":"Figure","type":"Plot"},"ticker":{"id":"ed457ccb-d82c-41d0-bc3d-11b5262bd275","type":"BasicTicker"}},"id":"c4483179-8af6-4f05-a6c6-c8eed0dfd7fb","type":"Grid"},{"attributes":{"axis_label":"x0","formatter":{"id":"943ff512-c009-4c9c-827e-553415ee9c82","type":"BasicTickFormatter"},"plot":{"id":"7b40001c-9253-4dd2-a062-dcc3107cc9e2","subtype":"Figure","type":"Plot"},"ticker":{"id":"747b8f58-5a6b-4485-a306-8c200e5ddf34","type":"BasicTicker"}},"id": ...
#             var render_items = [{"docid":"34628ee8-0fbe-4cb0-b190-88750b7bfd0b","elementid":"ce643022-8a8f-4b12-b6a9-13620177ebde","modelid":"7b40001c-9253-4dd2-a062-dcc3107cc9e2"}];
#
#             Bokeh.embed.embed_items(docs_json, render_items);
#           };
#           if (document.readyState != "loading") fn();
#           else document.addEventListener("DOMContentLoaded", fn);
#         })();
#       },
#       function(Bokeh) {
#       }
#     ];
#
#     function run_inline_js() {
#
#       if ((window.Bokeh !== undefined) || (force === true)) {
#         for (var i = 0; i < inline_js.length; i++) {
#           inline_js[i](window.Bokeh);
#         }if (force === true) {
#           display_loaded();
#         }} else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(run_inline_js, 100);
#       } else if (!window._bokeh_failed_load) {
#         console.log("Bokeh: BokehJS failed to load within specified timeout.");
#         window._bokeh_failed_load = true;
#       } else if (force !== true) {
#         var cell = $(document.getElementById("ce643022-8a8f-4b12-b6a9-13620177ebde")).parents('.cell').data().cell;
#         cell.output_area.append_execute_result(NB_LOAD_WARNING)
#       }
#
#     }
#
#     if (window._bokeh_is_loading === 0) {
#       console.log("Bokeh: BokehJS loaded, going straight to plotting");
#       run_inline_js();
#     } else {
#       load_libs(js_urls, function() {
#         console.log("Bokeh: BokehJS plotting callback run at", now());
#         run_inline_js();
#       });
#     }
#   }(this));
# </script>

# %% [markdown]
# ### RBA

# %% [markdown]
# #### Density estimation using logistic regression
# \begin{align}
#     \frac{P(X_{\text{tr}})}{P(X_{\text{tst}})} = \frac{P(X\mid s=\text{tr})}{P(X\mid s=\text{tst})}
#     &= \frac{\frac{P(s=\text{tr}\mid X)P(X)}{P(s=\text{tr})}}{\frac{P(s=\text{tst}\mid X)P(X)}{P(s=\text{tst})}} \\
#     &= \frac{P(s=\text{tr}\mid X)P(s=\text{tst})}{P(s=\text{tst}\mid X)P(s=\text{tr})} \\
#     &= \frac{P(s=\text{tst})}{P(s=\text{tr})}\frac{1-P(s=\text{tst}\mid X)}{P(s=\text{tst}\mid X)} \\
#     &= \frac{P(s=\text{tst})}{P(s=\text{tr})}(\frac{1}{P(s=\text{tst}\mid X)} - 1)
# \end{align}
#
# Hence we can find $P(s=\text{tst}\mid X)$ first and then calculate the ratio from it
# \begin{align}
# \text{minimize}_{w} -\log p(s=\text{tst}\mid x; w),
# \end{align}
# which is logistic regression on $x, s$
#
# A simplified version of the ratio is
# \begin{align}
#     &\frac{P(s=\text{tst})}{P(s=\text{tr})}(\frac{1}{P(s=\text{tst}\mid X)} - 1) \\
#     &=\frac{P(s=\text{tst})}{P(s=\text{tr})}(\frac{1}{\text{sigmoid}(-wX)} - 1) \\
#     &=\frac{P(s=\text{tst})}{P(s=\text{tr})}e^{-wX}
# \end{align}

# %%
tr = data.tr
tst = data.tst

# %%
n_tr = tr.y.shape[0]
n_tst = tst.y.shape[0]

x = tf.placeholder(tf.float32, [None, 2])
W = tf.Variable(tf.random_uniform(shape=[2, 1]), dtype=tf.float32)
b = tf.Variable(tf.random_uniform(shape=[1]), dtype=tf.float32)
logits = tf.matmul(x, W) + b
y = tf.nn.sigmoid(logits)
y_ = tf.placeholder(tf.float32, [None, 1])

cross_entropy = tf.nn.sigmoid_cross_entropy_with_logits(logits=logits, labels=y_)
# loss = tf.reduce_mean(cross_entropy + tf.nn.l2_loss(W))
loss = tf.reduce_mean(cross_entropy)
train_step = tf.train.RMSPropOptimizer(0.01).minimize(cross_entropy)

init = tf.global_variables_initializer()
sess = tf.Session()
sess.run(init)

s = np.concatenate((np.zeros(n_tr), np.ones(n_tst))).reshape(-1, 1)

for i in range(1000):
    sess.run(train_step, feed_dict={x: np.vstack((tr.X, tst.X)), y_: s})

correct_prediction = tf.equal(y > 0.5, y_ > 0.5)
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
print(sess.run(loss, feed_dict={x: np.vstack((tr.X, tst.X)), y_: s}))
print(sess.run(accuracy, feed_dict={x: np.vstack((tr.X, tst.X)), y_: s}))

def logi_classify_F(X):
    return sess.run(y, feed_dict={x: X})

data_gen.visualize_2D_classification(data, classifyF=logi_classify_F, fig_width=400)
# Out:
# 0.164329
# 0.92
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="761ff427-ca4c-4079-8e5e-d4fd1a877b7e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("761ff427-ca4c-4079-8e5e-d4fd1a877b7e");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("761ff427-ca4c-4079-8e5e-d4fd1a877b7e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '761ff427-ca4c-4079-8e5e-d4fd1a877b7e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"dc80472c-831e-427a-9904-7c16e8a7e6bc":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["x","y","dw","image","dh"],"data":{"dh":[11.144782679691108],"dw":[10.724794363064207],"image":[{"__ndarray__":"...","dtype":"uint32","shape":[150,150]}],"x":[-5.121759833021933],"y":[-4.601767090015657]}},"id":"325764a2-89ca-4c1a-8eb6-edf238de0ad5","type":"ColumnDataSource"},{"attributes":{"label":{"value":"Testing set, True"},"renderers":[{"id":"83f8b331-e0a0-440e-b73c-92d63edc0663","type":"GlyphRenderer"}]},"id":"9028e790-0927-4ab2-9f12-83bc1d569317","type":"LegendItem"},{"attributes":{"data_source":{"id":"9558508b-3bcb-4355-b88c-c824779907ee","type":"ColumnDataSource"},"glyph":{"id":"48f11054-1492-4e15-a233-24f6268154df","type":"Cross"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"752f1a88-30bd-4a51-9f4a-213374d1d66b","type":"Cross"},"selection_glyph":null},"id":"5058fb0a-9718-421b-9c10-6897e5f6b748","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"cad7b24a-179e-46ac-a171-e29ee2acf108","subtype":"Figure","type":"Plot"},"ticker":{"id":"62c44a67-44a8-4800-bd5e-e59ab97d0c90","type":"BasicTicker"}},"id":"d101dc53-1843-4c5b-b33e-4714089282f8","type":"Grid"},{"attributes":{"plot":{"id":"cad7b24a-179e-46ac-a171-e29ee2acf108","subtype":"Figure","type":"Plot"}},"id":"37648a4d-6588-49c7-b834-72cb966f2b8b","type":"WheelZoomTool"},{"attributes":{"data_source":{"id":"88324d22-971b-4c6c-8418-0014dd6e7932","type":"ColumnDataSource"},"glyph":{"id":"65eb340a-1adf-4f04-afb0-ad7410837787","type":"Cross"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"e60e851d-b1ee-4cd5-a453-3d49a056ebe4","type":"Cross"},"selection_glyph":null},"id":"26935908-23d0-46a3-9968-78d88fe74cf5","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[153]},"y":{"__ndarray__":"...","dtype":"float64","shape":[153]}}},"id":"9558508b-3bcb-4355-b88c-c824779907ee","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.6},"fill_color":{"value":"#298873"},"line_alpha":{"value":0.6},"line_color":{"value":"#298873"},"line_width":{"value":1.5},"size":{"units":"screen","value":9},"x":{"field":"x"},"y":{"field":"y"}},"id":"b5767e2e-8138-48a5-9410-1f19dec7ed27","type":"Circle"},{"attributes":{"data_source":{"id":"325764a2-89ca-4c1a-8eb6-edf238de0ad5","type":"ColumnDataSource"},"glyph":{"id":"5ed5035d-1aac-4733-b987-e3dc3c99732d","type":"ImageRGBA"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"fc6a8ae4-e9a5-44f6-ad0c-3489fa7fe7c2","type":"ImageRGBA"},"selection_glyph":null},"id":"fb82683e-f37e-4200-9810-b3186572b94e","type":"GlyphRenderer"},{"attributes":{"dh":{"field":"dh","units":"data"},"dw":{"field":"dw","units":"data"},"image":{"field":"image"},"x":{"field":"x"},"y":{"field":"y"}},"id":"5ed5035d-1aac-4733-b987-e3dc3c99732d","type":"ImageRGBA"},{"attributes":{"dimension":1,"plot":{"id":"cad7b24a-179e-46ac-a171-e29ee2acf108","subtype":"Figure","type":"Plot"},"ticker":{"id":"bad456f5-7da3-4207-8f35-2b42188f95fe","type":"BasicTicker"}},"id":"b3622f80-9483-4eb5-97f8-f91795616bf1","type":"Grid"},{"attributes":{"plot":{"id":"cad7b24a-179e-46ac-a171-e29ee2acf108","subtype":"Figure","type":"Plot"}},"id":"6c9c489a-5a40-4dbf-a7a3-c1c2032ef45d","type":"SaveTool"},{"attributes":{"plot":{"id":"cad7b24a-179e-46ac-a171-e29ee2acf108","subtype":"Figure","type":"Plot"}},"id":"88f5f2a2-05d2-4edd-9846-cad8a2d5fa43","type":"HelpTool"},{"attributes":{},"id":"bad456f5-7da3-4207-8f35-2b42188f95fe","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[167]},"y":{"__ndarray__":"...","dtype":"float64","shape":[167]}}},"id":"88324d22-971b-4c6c-8418-0014dd6e7932","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_wi ...

# %%
def logi_reweight_F(X):
    _R = sess.run(n_tst/n_tr*(tf.exp(logits)), feed_dict={x: X})
    # _R = sess.run(n_tst/n_tr*(tf.exp(-logits)), feed_dict={x: X})
    return _R

plt.hist(-1/logi_reweight_F(data.tst.X))
plt.show()
# Out:
# array([[ 0.0022937]], dtype=float32)

# %%
def mixed_moments_tf(_t, order):
    if order == 1:
        return _t
    n_vars = _t.get_shape()[1]
    r = [tf.expand_dims(_t[:, i], axis=1) * mixed_moments_tf(_t[:, i:], order - 1) for i in range(n_vars)]
    return tf.concat(r, axis=1)


def get_moments(_x, order):
    # The hack by https://github.com/tensorflow/tensorflow/issues/956
    _t = tf.pad(_x - 1, [[0, 0], [1, 0]], 'CONSTANT') + 1
    return mixed_moments_tf(_t, order)

var_x = tf.Variable(tr.X)
moment_x = get_moments(var_x, 3)
with tf.Session() as _sess:
    _sess.run(var_x.initializer)
    momentx = _sess.run(moment_x)

# %%
n_classes = 2
ys = np.eye(n_classes)

# %%
tr_y_1hot = np.hstack((tr.y, 1 - tr.y))
m_tr = get_moments(tr.X, 1).T
m_tr = m_tr[:, :, np.newaxis, np.newaxis]
# tr_y_1hot.shape
tr_y_1hot_4D = tr_y_1hot[:, np.newaxis, :, np.newaxis]
m_tr.shape
# Out:
# (320, 10, 1, 1)

# %%
min_eps = 0.0001
max_iter = 10000
lr = 0.0001
l_theta = 0.5
theta = np.zeros((10, n_classes))

# %%
def softmax(x, max_dim):
    e_x = np.exp(x - np.max(x, axis=max_dim, keepdims=True))
    return e_x / e_x.sum(axis=max_dim, keepdims=True)

def RBA_predict(x, theta):
    m = get_moments(x, 1).T
    m_d = m[:,:, np.newaxis, np.newaxis]*ys[np.newaxis, np.newaxis, :, :]
    # m_d.shape = (n_data, n_moments, n_classes, n_classes)
    pm_c = -1/logi_reweight_F(x)[:, :, np.newaxis, np.newaxis]*m_d*theta[np.newaxis, :, :, np.newaxis]
    p_c = np.sum(pm_c, axis=1, keepdims=True)
    return softmax(p_c, 3)

m_all = get_moments(data.X, 1).T
m_d_all = m_all[:,:, np.newaxis, np.newaxis]*ys[np.newaxis, np.newaxis, :, :]
reweight_all = logi_reweight_F(data.X)
def RBA_predict_all(theta):
    pm_c = -1/reweight_all[:, :, np.newaxis, np.newaxis]*m_d_all*theta[np.newaxis, :, :, np.newaxis]
    p_c = np.sum(pm_c, axis=1, keepdims=True)
    return softmax(p_c, 3)
    
def E(_m, _p):
    _Em = np.mean(_m*_p, axis=0)
    return np.sum(_Em, axis=2)

E_m_tr = E(m_tr, tr_y_1hot_4D)
    
_iter = 0
while True:
    _iter += 1
    pred = RBA_predict_all(theta) 
    dL = E_m_tr - E(m_d_all, pred)
    regular_grad = 2*theta/(np.linalg.norm(theta.ravel()) + 1e-9)
    theta_inc = dL + l_theta*regular_grad
    theta -= lr * theta_inc
    eps = np.linalg.norm(theta_inc)
    if not (_iter % 1000): # and _iter % 1001 and _iter % 1002):
        print(eps, np.linalg.norm(theta.ravel()))
        # print(theta.T)
        # print(l_theta*regular_grad.T)
    if eps < min_eps or _iter >= max_iter: 
        break
# Out:
# 1.28141329014 0.193215180298
# 0.963090619519 0.299807172456
# 0.816176745168 0.384969706563
# 0.730676461198 0.459158772167
# 0.669735271353 0.526288277083
# 0.631046167804 0.588601319132
# 0.597335416497 0.647357477916
# 0.567987928567 0.703295806892
# 0.545740380213 0.756841163025
# 0.525501152991 0.808457814335

# %%
def RBA_F(x):
    pred = RBA_predict(x, theta)
    np.set_printoptions(precision=2, suppress=True)
    print(pred[0:5,0,:,:])
    np.set_printoptions(precision=8, suppress=False)
    print(pred.shape)
    
    return pred[:, 0, 0, 0]
data_gen.visualize_2D_classification(data, classifyF=RBA_F, fig_width=600)
# Out:
# [[[ 0.47  0.53]
#   [ 0.51  0.49]]
#
#  [[ 0.47  0.53]
#   [ 0.51  0.49]]
#
#  [[ 0.47  0.53]
#   [ 0.51  0.49]]
#
#  [[ 0.46  0.54]
#   [ 0.51  0.49]]
#
#  [[ 0.46  0.54]
#   [ 0.51  0.49]]]
# (22500, 1, 2, 2)
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="99781813-315a-4447-b6c9-b8f02ab09f82"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("99781813-315a-4447-b6c9-b8f02ab09f82");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("99781813-315a-4447-b6c9-b8f02ab09f82");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '99781813-315a-4447-b6c9-b8f02ab09f82' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"79e45ace-be72-4c0b-80fa-e9d5eb1b36d6":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":1.5},"size":{"units":"screen","value":9},"x":{"field":"x"},"y":{"field":"y"}},"id":"1ef843fa-0a6f-41d5-9458-3f7beffa608e","type":"Cross"},{"attributes":{},"id":"326af9d1-791e-4162-8608-85052f5208de","type":"ToolEvents"},{"attributes":{"fill_alpha":{"value":0.6},"fill_color":{"value":"#cc3d42"},"line_alpha":{"value":0.6},"line_color":{"value":"#cc3d42"},"line_width":{"value":1.5},"size":{"units":"screen","value":9},"x":{"field":"x"},"y":{"field":"y"}},"id":"049f34f1-76ab-4e13-b253-315a32631370","type":"Cross"},{"attributes":{"fill_alpha":{"value":0.6},"fill_color":{"value":"#3d84cc"},"line_alpha":{"value":0.6},"line_color":{"value":"#3d84cc"},"line_width":{"value":1.5},"size":{"units":"screen","value":9},"x":{"field":"x"},"y":{"field":"y"}},"id":"8a216f30-d4b1-4799-a1ed-9f0bbed63bc4","type":"Cross"},{"attributes":{"dh":{"field":"dh","units":"data"},"dw":{"field":"dw","units":"data"},"image":{"field":"image"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d6dbb4b5-0f69-4473-a8a9-935251f722a9","type":"ImageRGBA"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"012a0388-cf28-48dc-b9a2-f8329ae3335e","type":"PanTool"},{"id":"cf18190b-d219-415b-b27f-04ccb579d15b","type":"WheelZoomTool"},{"id":"f3396ee9-3f59-4129-b6c6-5020c7ebb5e9","type":"BoxZoomTool"},{"id":"97f740f4-88ce-4f49-ab5d-326f16601643","type":"SaveTool"},{"id":"e6ea36ef-0fbd-4f35-8b04-a4d824eebd4e","type":"ResetTool"},{"id":"6cbef777-1b84-4875-b041-974faba44ed7","type":"HelpTool"}]},"id":"86390ca3-9ed1-436c-b1d7-9d5f389388e6","type":"Toolbar"},{"attributes":{"label":{"value":"Testing set, False"},"renderers":[{"id":"6758f668-09d8-456b-b6ab-f63327302ae2","type":"GlyphRenderer"}]},"id":"4c6bfde5-b113-435a-9f43-ba708ad17777","type":"LegendItem"},{"attributes":{"plot":{"id":"679834ab-25df-49b3-95b4-8e248b3687b5","subtype":"Figure","type":"Plot"}},"id":"97f740f4-88ce-4f49-ab5d-326f16601643","type":"SaveTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"b448a98a-4fcc-40fb-a882-c08b05b3a771","type":"BoxAnnotation"},{"attributes":{"below":[{"id":"d05a4747-64ab-47d8-aa68-247124559885","type":"LinearAxis"}],"left":[{"id":"0e7db323-5107-4d42-becb-00731ce3cd29","type":"LinearAxis"}],"renderers":[{"id":"d05a4747-64ab-47d8-aa68-247124559885","type":"LinearAxis"},{"id":"f78fed4b-48f1-4c37-9a4e-f099ab84f76f","type":"Grid"},{"id":"0e7db323-5107-4d42-becb-00731ce3cd29","type":"LinearAxis"},{"id":"e4df9e3a-7772-4ab6-bfae-3cc4de5ff4be","type":"Grid"},{"id":"b448a98a-4fcc-40fb-a882-c08b05b3a771","type":"BoxAnnotation"},{"id":"a1a3bf6b-4d77-45a5-b562-3731b80d10be","type":"GlyphRenderer"},{"id":"ef7de6b3-c762-4772-a790-85b8405e900c","type":"GlyphRenderer"},{"id":"b3651457-7260-43e5-a03a-f7aea7da9b70","type":"Legend"},{"id":"9b8222ac-de17-442a-8b64-b211ae536c60","type":"GlyphRenderer"},{"id":"4ee4bbbf-a375-48e4-a5fe-1ddfcbf42108","type":"GlyphRenderer"},{"id":"b0513885-e1e0-4a9d-b29d-a2a463f4b0e6","type":"GlyphRenderer"},{"id":"6758f668-09d8-456b-b6ab-f63327302ae2","type":"GlyphRenderer"}],"title":{"id":"8c634c6c-d623-4088-ab78-c62c36a322b5","type":"Title"},"tool_events":{"id":"326af9d1-791e-4162-8608-85052f5208de","type":"ToolEvents"},"toolbar":{"id":"86390ca3-9ed1-436c-b1d7-9d5f389388e6","type":"Toolbar"},"x_range":{"id":"ab285e34-c9ed-43f9-b512-6782b94bc5a2","type":"Range1d"},"y_range":{"id":"3cda1903-297e-4521-b8cc-0cf35615ee1d","type":"Range1d"}},"id":"679834ab-25df-49b3-95b4-8e248b3687b5","subtype":"Figure","type":"Plot"},{"attr ...
